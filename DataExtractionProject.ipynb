# %% [markdown]
# # GDP Data extraction and processing.
# ### An international firm that is looking to expand its business in different countries across the world has recruited you. You have been hired as a junior Data Engineer and are tasked with creating a script that can extract the list of the top 10 largest economies of the world in descending order of their GDPs in Billion USD (rounded to 2 decimal places), as logged by the International Monetary Fund (IMF).

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Downloading lxml-6.0.0-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 2.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/4.0 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.0.0

# %%
import pandas as pd
import numpy as np
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
tables = pd.read_html(URL)
print(f"Total Tables found: {len(tables)}")
# Out:
# Total Tables found: 8

# %%
df = tables[3]
df.columns = range(df.shape[1])
df = df[[0,2]]
df = df.iloc[1:11,:]
df.columns = ['Country','GDP (Million USD)']

# %%
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)
df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000
df[['GDP (Million USD)']] = np.round(df[['GDP (Million USD)']], 2)
df.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %%
df.to_csv("./Largest_economies.csv")

# %%
import requests
import os
from PIL import Image
from IPython.display import IFrame
url='https://www.ibm.com/'
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=0EC3B239D1633B61B2471D0CAC532F3C~-1~...~-1~-1~-1; bm_sz=6C2D37B174F06BFEC274CBA18BC0A574~~3422001~3748677'}

# %%
print(r.request.body)
# Out:
# None

# %%
header= r.headers
print(header)
# Out:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Thu, 24 Jul 2025 14:13:44 GMT', 'ETag': 'W/"2b968-63aad6edf76d3-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=600', 'Expires': 'Thu, 24 Jul 2025 14:26:50 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Thu, 24 Jul 2025 14:16:50 GMT', 'Content-Length': '33026', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
print(header['Date'])
print(header['Content-Type'])
# Out:
# Thu, 24 Jul 2025 14:16:50 GMT
# text/html;charset=utf-8

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:100]
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n  '

# %%
url2='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png'
r1 = requests.get(url2)

# %%
print(r1.headers)
# Out:
# {'Date': 'Thu, 24 Jul 2025 14:21:26 GMT', 'X-Clv-Request-Id': '26834fb5-1ce8-43db-85fc-1d32e27449dc', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': '26834fb5-1ce8-43db-85fc-1d32e27449dc', 'ETag': '"8bb44578fff8fdcc3d2972be9ece0164"', 'Content-Type': 'image/png', 'Last-Modified': 'Wed, 16 Nov 2022 03:32:41 GMT', 'Content-Length': '78776'}

# %%
r1.headers['Content-Type']
# Out:
# 'image/png'

# %%
path=os.path.join(os.getcwd(),'image.png')

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %%
url3 = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt"
path=os.path.join(os.getcwd(),'example1.txt')
r3 = requests.get(url3)
with open(path,'wb') as f:
    f.write(r3.content)

# %%
r3.status_code
# Out:
# 200

# %%
print(r3.headers)
# Out:
# {'Date': 'Thu, 24 Jul 2025 14:26:06 GMT', 'X-Clv-Request-Id': 'bc5cd003-b517-4f3c-b217-61f8014f3137', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': 'bc5cd003-b517-4f3c-b217-61f8014f3137', 'Cache-Control': 'max-age=0,public', 'ETag': '"522bc63a850f3569b8924c51131d5fe4"', 'Content-Type': 'text/plain', 'Last-Modified': 'Wed, 12 Oct 2022 22:36:17 GMT', 'Content-Length': '45'}
