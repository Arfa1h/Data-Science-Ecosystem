# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# **comments and keywords**\
# ***comments are used to  explain code and make it more readable.
# They are not executed***\
# ****1. Single line comment\
#     starts with # symbol\
#     used for short single line explanations or notes\
# 2. Multiline Comment\ Docstring \
#     text within ''' ''' or """ """\
#     used for multi line commenting or paragrap****\
#
#
# ***keywords:***\
#         ****they are resereved words that have special meaning and cannot be used as
#         variable names or function names or identifiers. these are sed to define the
#         syntax and structure of python language.\
#             ex: if, for, True, False, import, while etc.,****

# %%
# output function print()
print("Good Afternoon")
# Out:
# Good Afternoon

# %%
name = input("Enter your name")
place = input("Enter your Place")
print(f"My name is {name} and i am from {place}")
# Out:
# Enter your name Arfath
# Enter your Place Davangere
# My name is Arfath and i am from Davangere

# %%
print("my name is {} and i am from {}".format(name,place))
# Out:
# my name is Arfath and i am from Davangere

# %%
a = int(input("enter a number"))
b = int(input("enter anther number"))
c = a+b
print("sum is",c)
# Out:
# enter a number 45
# enter anther number 45
# sum is 90

# %%
l = float(input("what is the length of the rectangle"))
b = float(input("what is the breadth of the rectangle"))
r = float(input("what is the radius of the circle"))
aor = l*b
print("area of rectangle is", aor)
print("area f circle is", 3.14*r*r)
# Out:
# what is the length of the rectangle 23
# what is the breadth of the rectangle 34
# what is the radius of the circle 1.2
# area of rectangle is 782.0
# area f circle is 4.521599999999999
