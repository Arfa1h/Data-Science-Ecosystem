# %%
Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6}

# %%
Dict["key1"]
# Out:
# 1

# %%
Dict[(0,1)]
# Out:
# 6

# %%
movie = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
movie
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
movie.keys()
# Out:
# dict_keys(['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell', 'Their Greatest Hits (1971-1975)', 'Saturday Night Fever', 'Rumours'])

# %%
movie["Back in Black"]
# Out:
# '1980'

# %%
movie.values()
# Out:
# dict_values(['1980', '1973', '1992', '1977', '1976', '1977', '1977'])

# %%
del(movie["Thriller"])
movie
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
"The Bodyguard" in movie
# Out:
# True

# %%
store={}

# %%
ProductNo1 = "Mobile Phone"
ProductNo1_quantity = 5
ProductNo1_price = 20000
ProductNo1_releaseYear= 2020

# %%
store["ProductNo1"]= ProductNo1
store["ProductNo1_quantity"]= ProductNo1_quantity
store["ProductNo1_price"]= ProductNo1_price
store["ProductNo1_releaseYear"]=ProductNo1_releaseYear

# %%
store
# Out:
# {'ProductNo1': 'Mobile Phone',
#  'ProductNo1_quantity': 5,
#  'ProductNo1_price': 20000,
#  'ProductNo1_releaseYear': 2020}

# %%
ProductNo2 = "Laptop"
ProductNo2_quantity = 10
ProductNo2_price = 50000
ProductNo2_releaseYear= 2023

# %%
store["ProductNo2"]= ProductNo2
store["ProductNo2_quantity"]= ProductNo2_quantity
store["ProductNo2_price"]= ProductNo2_price
store["ProductNo2_releaseYear"]=ProductNo2_releaseYear

# %%
store["ProductNo2_releaseYear"]
# Out:
# 2023

# %%
store["ProductNo1_releaseYear"]
# Out:
# 2020

# %%
"ProductNo1_releaseYear" in store 
"ProductNo2_releaseYear" in store
# Out:
# True

# %%
list(store.keys())
# Out:
# ['ProductNo1',
#  'ProductNo1_quantity',
#  'ProductNo1_price',
#  'ProductNo1_releaseYear',
#  'ProductNo2',
#  'ProductNo2_quantity',
#  'ProductNo2_price',
#  'ProductNo2_releaseYear']
