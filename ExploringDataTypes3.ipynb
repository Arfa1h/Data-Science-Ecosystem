# %%
l = ["Arfath",10.1,4,"pop"]
l[0:5:2]
# Out:
# ['Arfath', 4]

# %%
l.append(["Mohasin",30])
l
# Out:
# ['Arfath', 10.1, 4, 'pop', ['Mohasin', 30]]

# %%
l.extend(["Moin",67])
l
# Out:
# ['Arfath', 10.1, 4, 'pop', ['Mohasin', 30], 'Moin', 67]

# %%
l[4][0][3]
# Out:
# 'a'

# %%
print("before change l:",l)
l[1]=40
print("after change l:",l)
# Out:
# before change l: ['Arfath', 40, 4, 'pop', ['Mohasin', 30], 'Moin', 67]
# after change l: ['Arfath', 40, 4, 'pop', ['Mohasin', 30], 'Moin', 67]

# %%
del(l[2])
l
# Out:
# ['Arfath', 40, 'pop', ['Mohasin', 30], 'Moin', 67]

# %%
p=l[:]
p[0]="moin"
p
# Out:
# ['moin', 40, 'pop', ['Mohasin', 30], 'Moin', 67]

# %%
l
# Out:
# ['Arfath', 40, 'pop', ['Mohasin', 30], 'Moin', 67]

# %%
A=[1,'a']
B=[2,1,'d']
A.extend(B)
A
# Out:
# [1, 'a', 2, 1, 'd']
