# %%
name = "Bodyguard"
print(name[0])
# Out:
# B

# %%
name[6]
# Out:
# 'a'

# %%
print(name[4])
# Out:
# g

# %%
len(name)
# Out:
# 9

# %%
name[0:4]
# Out:
# 'Body'

# %%
name[0:9:4]
# Out:
# 'Bgd'

# %%
name[::2]
# Out:
# 'Bdgad'

# %%
sentence = name + " is my name"

# %%
print(r"{sentence} \n is the best movie")
# Out:
# {sentence} \n is the best movie

# %%
sentence*3
# Out:
# 'Bodyguard is my nameBodyguard is my nameBodyguard is my name'

# %%
print ("sentence before uppercase:",sentence)
# Out:
# sentence before uppercase: Bodyguard is my name

# %%
big=sentence.upper()
print(big)
# Out:
# BODYGUARD IS MY NAME

# %%
c=sentence.replace('Bodyguard','arfath')
print(c)
# Out:
# arfath is my name

# %%
sentence.find('name')
# Out:
# 16

# %%
split_string=(sentence.split())
split_string
# Out:
# ['Bodyguard', 'is', 'my', 'name']

# %%
import re
pattern=r"Body"
result=re.search(pattern,sentence)
if result:
    print('Match found!')
else:
    print('no match!')
# Out:
# Match found!

# %%
pattern = r"\d\d\d\d\d\d\d\d\d\d"  # Matches any ten consecutive digits
text = "My Phone number is 1234567890"
match = re.search(pattern, text)

if match:
    print("Phone number found:", match.group())
else:
    print("No match")
# Out:
# Phone number found: 1234567890

# %%
pattern = r"\W"  # Matches any non-word character
text = "Hello, world!"
matches = re.findall(pattern, text)

print("Matches:", matches)
# Out:
# Matches: [',', ' ', '!']

# %%
s2 = "The BodyGuard is the best album of 'Whitney Houston'."


# Use the findall() function to find all occurrences of the "st" in the string
result = re.findall("st", s2)

# Print out the list of matched words
print(result)
# Out:
# ['st', 'st']

# %%
# Define the regular expression pattern to search for
pattern = r"Bodyguard"

# Define the replacement string
replacement = "legend"

# Use the sub function to replace the pattern with the replacement string
new_string = re.sub(pattern, replacement, sentence, flags=re.IGNORECASE)

# The new_string contains the original string with the pattern replaced by the replacement string
print(new_string)
# Out:
# legend is my name

# %%
print("Python is \"awesome\"")
# Out:
# Python is "awesome"
