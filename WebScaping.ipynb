# %%
pip install --upgrade beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\mohammed arfath\appdata\local\programs\python\python312\lib\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mohammed arfath\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mohammed arfath\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter("ignore")

# %%
from bs4 import BeautifulSoup
import requests

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
tag_object=soup.title
print("tag_object",tag_object)
# Out:
# tag_object <title>Page Title</title>

# %%
print(type(tag_object))
# Out:
# <class 'bs4.element.Tag'>

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child = soup.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
parent_tag = tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling_1 = tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2 = sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %%
tag_child['id']
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %% [markdown]
# # Table

# %%
table="<table><tr><td id='flight' >Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a> </td><td>80 kg</td></tr></table>"

# %%
tsoup = BeautifulSoup(table,"html.parser")
print(tsoup.prettify())
# Out:
# <table>
#  <tr>
#   <td id="flight">
#    Flight No
#   </td>
#   <td>
#    Launch site
#   </td>
#   <td>
#    Payload mass
#   </td>
#  </tr>
#  <tr>
#   <td>
#    1
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Florida">
#     Florida
#    </a>
#   </td>
#   <td>
#    300 kg
#   </td>
#  </tr>
#  <tr>
#   <td>
#    2
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Texas">
#     Texas
#    </a>
#   </td>
#   <td>
#    94 kg
#   </td>
#  </tr>
#  <tr>
#   <td>
#    3
#   </td>
#   <td>
#    <a href="https://en.wikipedia.org/wiki/Florida">
#     Florida
#    </a>
#   </td>
#   <td>
#    80 kg
#   </td>
#  </tr>
# </table>

# %%
table_rows = tsoup.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>]

# %%
first_row = table_rows[0]
first_row
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i,row in enumerate (table_rows):
    print("row",i,"is",row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>
# row 1 is <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td><td>80 kg</td></tr>

# %%
for i, row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j, cell in enumerate(cells):
        print('column',j,"cell",cell)
# Out:
# row 0
# column 0 cell <td id="flight">Flight No</td>
# column 1 cell <td>Launch site</td>
# column 2 cell <td>Payload mass</td>
# row 1
# column 0 cell <td>1</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>
# column 2 cell <td>300 kg</td>
# row 2
# column 0 cell <td>2</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# column 2 cell <td>94 kg</td>
# row 3
# column 0 cell <td>3</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a> </td>
# column 2 cell <td>80 kg</td>

# %%
tsoup.find_all('a',href=False)
# Out:
# []
